# %%
import asyncio
from hud import gym
from hud.agent import OperatorAgent # Replace with an agent that can achieve the task
from hud import create_job, load_taskset

from hud.types import CustomGym
from pathlib import Path
from hud.task import Task
from hud.taskset import TaskSet

from dotenv import load_dotenv
import os
import json
import pprint
from openai import AsyncOpenAI

load_dotenv()
assert os.environ.get("HUD_API_KEY")
assert os.environ.get("OPENAI_API_KEY")

# %%
taskset = await load_taskset("hud-appflowy-taskset-368-final")
print(f"Number of tasks: {len(taskset)}")

first_task = taskset[0]
pprint.pprint(first_task.__dict__)
# Out:
# Number of tasks: 368
# {'config': None,
#  'description': None,
#  'evaluate': FunctionConfig(function='grade', args=['rockbnb-add-richmond-property'], id=None, metadata=None),
#  'gym': CustomGym(type='public', location='remote', image_or_build_context='156041433621.dkr.ecr.us-east-1.amazonaws.com/docker-gym:6f368c40-4812-44b0-8478-730a72d31fdd', host_config=None),
#  'id': 'f560b955-a804-4b4e-a31a-43dcae30fa28',
#  'metadata': None,
#  'prompt': 'We need to expand our Richmond district portfolio. Please add the '
#            'Richmond Garden House (identifier PROP-007) to our bookkeeping '
#            'system. This 3-bedroom property in the Richmond neighborhood '
#            'should be marked as Active with Master-lease host type, occupancy '
#            'rate of 0.78, guest rating of 4.72, and scheduled for next '
#            'turnover on 2025-05-21 at 14:00.',
#  'setup': FunctionConfig(function='setup', args=['rockbnb-add-richmond-property'], id=None, metadata=None)}

# %%
# This will take 2-3 minutes to set up the environment
env = await gym.make(env_src=first_task)

print("Environment resetting (runs setup)...")
obs, _ = await env.reset() 
print(f"Initial observation: {obs}")

client = AsyncOpenAI(api_key=os.environ["OPENAI_API_KEY"])
agent = OperatorAgent(client=client)
# Out:
# setup produced stderr:
# [06/05/25 00:32:53] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     Starting AppFlowy server            appflowy.py:128
#                     INFO     Starting PostgreSQL server for problem  setup.py:29
#                              template rockbnb
#                     INFO     Starting PostgreSQL server...           utils.py:11
#                     DEBUG    Command to run: /usr/bin/sudo -u        utils.py:25
#                              postgres
#                              /usr/lib/postgresql/16/bin/postgres -D
#                              /var/lib/postgresql/16/main -c
#                              config_file=/etc/postgresql/16/main/pos
#                              tgresql.conf
#                     INFO     Launched PostgreSQL process with PID 13 utils.py:28
#                     INFO     Waiting for PostgreSQL to accept        utils.py:29
#                              connections
#                     DEBUG    Postgres not ready yet, retrying...     utils.py:36
#                     INFO     PostgreSQL is now ready to accept       utils.py:38
#                              connections
#                     INFO     Loading SQL definitions for problem     setup.py:32
#                              template rockbnb
# [06/05/25 00:32:55] INFO     Stopping PostgreSQL server for problem  setup.py:42
#                              template rockbnb
#                     INFO     Stopping PostgreSQL server with PID 13  utils.py:43
#                     INFO     Sent SIGTERM to PostgreSQL process      utils.py:49
#                     INFO     PostgreSQL server stopped               utils.py:51
#                     INFO     Copying MinIO data to /data             setup.py:46
# [06/05/25 00:32:56] INFO     Starting dinit                          setup.py:54
#                     INFO     Loading service definitions from manual_dinit.py:39
#                              /etc/dinit.d
#                     DEBUG    Loading service file             manual_dinit.py:45
#                              admin_frontend
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/admin_frontend
#                     DEBUG    Registering service              manual_dinit.py:60
#                              'admin_frontend' from file
#                              /etc/dinit.d/admin_frontend
#                     DEBUG    Parsed config for                manual_dinit.py:62
#                              admin_frontend: {'type':
#                              ['process'], 'command': ['bash
#                              -c "sleep 3 &&
#                              /usr/local/bin/admin_frontend"']
#                              , 'logfile':
#                              ['/var/log/dinit/admin_frontend.
#                              log'], 'smooth-recovery':
#                              ['true'], 'depends-on':
#                              ['appflowy_cloud']}
#                     INFO     Registered service               manual_dinit.py:96
#                              admin_frontend (type=process)
#                              with dependencies
#                              ['appflowy_cloud']
#                     DEBUG    Service admin_frontend declares manual_dinit.py:101
#                              dependency appflowy_cloud
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file
#                              /etc/dinit.d/appflowy_cloud for
#                              service admin_frontend
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/appflowy_cloud
#                     DEBUG    Registering service              manual_dinit.py:60
#                              'appflowy_cloud' from file
#                              /etc/dinit.d/appflowy_cloud
#                     DEBUG    Parsed config for                manual_dinit.py:62
#                              appflowy_cloud: {'type':
#                              ['process'], 'command':
#                              ['/usr/bin/bash -c "export
#                              PORT=8000 && sleep 5 &&
#                              /usr/local/bin/appflowy_cloud"']
#                              , 'logfile':
#                              ['/var/log/dinit/appflowy_cloud.
#                              log'], 'smooth-recovery':
#                              ['true'], 'depends-on':
#                              ['setup_postgres_env', 'redis',
#                              'gotrue', 'minio']}
#                     INFO     Registered service               manual_dinit.py:96
#                              appflowy_cloud (type=process)
#                              with dependencies
#                              ['setup_postgres_env', 'redis',
#                              'gotrue', 'minio']
#                     DEBUG    Service appflowy_cloud declares manual_dinit.py:101
#                              dependency setup_postgres_env
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file
#                              /etc/dinit.d/setup_postgres_env
#                              for service appflowy_cloud
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/setup_postgres_env
#                     DEBUG    Registering service              manual_dinit.py:60
#                              'setup_postgres_env' from file
#                              /etc/dinit.d/setup_postgres_env
#                     DEBUG    Parsed config for                manual_dinit.py:62
#                              setup_postgres_env: {'type':
#                              ['scripted'], 'command':
#                              ['/usr/bin/sudo -E -u postgres
#                              /etc/dinit.d/setup_postgres_env.
#                              sh'], 'logfile':
#                              ['/var/log/dinit/setup_postgres_
#                              env.log'], 'waits-for':
#                              ['postgres'], 'restart':
#                              ['true']}
#                     DEBUG    Service setup_postgres_env       manual_dinit.py:69
#                              declares waits-for dependency
#                              postgres
#                     INFO     Registered service               manual_dinit.py:96
#                              setup_postgres_env
#                              (type=scripted) with
#                              dependencies ['postgres']
#                     DEBUG    Service setup_postgres_env      manual_dinit.py:101
#                              declares dependency postgres
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file /etc/dinit.d/postgres for
#                              service setup_postgres_env
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/postgres
#                     DEBUG    Registering service 'postgres'   manual_dinit.py:60
#                              from file /etc/dinit.d/postgres
#                     DEBUG    Parsed config for postgres:      manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['sudo -u postgres
#                              /usr/lib/postgresql/16/bin/postg
#                              res -D
#                              /var/lib/postgresql/16/main -c
#                              config_file=/etc/postgresql/16/m
#                              ain/postgresql.conf'],
#                              'stop-command':
#                              ['/usr/bin/pg_ctl -D
#                              /var/lib/postgresql/16/main stop
#                              -m fast -w'], 'logfile':
#                              ['/var/log/dinit/postgres.log'],
#                              'depends-on':
#                              ['setup_postgres_data']}
#                     INFO     Registered service postgres      manual_dinit.py:96
#                              (type=process) with dependencies
#                              ['setup_postgres_data']
#                     DEBUG    Service postgres declares       manual_dinit.py:101
#                              dependency setup_postgres_data
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file
#                              /etc/dinit.d/setup_postgres_dat
#                              a for service postgres
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/setup_postgres_data
#                     DEBUG    Registering service              manual_dinit.py:60
#                              'setup_postgres_data' from file
#                              /etc/dinit.d/setup_postgres_data
#                     DEBUG    Parsed config for                manual_dinit.py:62
#                              setup_postgres_data: {'type':
#                              ['scripted'], 'command':
#                              ['/etc/dinit.d/setup_postgres_da
#                              ta.sh'], 'logfile':
#                              ['/var/log/dinit/setup_postgres_
#                              data.log']}
#                     INFO     Registered service               manual_dinit.py:96
#                              setup_postgres_data
#                              (type=scripted) with
#                              dependencies []
#                     DEBUG    Service appflowy_cloud declares manual_dinit.py:101
#                              dependency redis
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file /etc/dinit.d/redis for
#                              service appflowy_cloud
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/redis
#                     DEBUG    Registering service 'redis' from manual_dinit.py:60
#                              file /etc/dinit.d/redis
#                     DEBUG    Parsed config for redis:         manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['redis-server --bind 0.0.0.0
#                              --protected-mode no'],
#                              'logfile':
#                              ['/var/log/dinit/redis.log'],
#                              'smooth-recovery': ['true']}
#                     INFO     Registered service redis         manual_dinit.py:96
#                              (type=process) with dependencies
#                              []
#                     DEBUG    Service appflowy_cloud declares manual_dinit.py:101
#                              dependency gotrue
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file /etc/dinit.d/gotrue for
#                              service appflowy_cloud
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/gotrue
#                     DEBUG    Registering service 'gotrue'     manual_dinit.py:60
#                              from file /etc/dinit.d/gotrue
#                     DEBUG    Parsed config for gotrue:        manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['/usr/bin/sudo -E -u supabase
#                              /etc/dinit.d/gotrue.sh'],
#                              'logfile':
#                              ['/var/log/dinit/gotrue.log'],
#                              'smooth-recovery': ['true'],
#                              'restart': ['true'],
#                              'depends-on':
#                              ['setup_postgres_env']}
#                     INFO     Registered service gotrue        manual_dinit.py:96
#                              (type=process) with dependencies
#                              ['setup_postgres_env']
#                     DEBUG    Service gotrue declares         manual_dinit.py:101
#                              dependency setup_postgres_env
#                     DEBUG    Service appflowy_cloud declares manual_dinit.py:101
#                              dependency minio
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file /etc/dinit.d/minio for
#                              service appflowy_cloud
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/minio
#                     DEBUG    Registering service 'minio' from manual_dinit.py:60
#                              file /etc/dinit.d/minio
#                     DEBUG    Parsed config for minio:         manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['/usr/local/bin/minio server
#                              /data --console-address
#                              ":9001"'], 'logfile':
#                              ['/var/log/dinit/minio.log']}
#                     INFO     Registered service minio         manual_dinit.py:96
#                              (type=process) with dependencies
#                              []
#                     DEBUG    Loading service file             manual_dinit.py:45
#                              appflowy_cloud
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/appflowy_cloud
#                     DEBUG    Service appflowy_cloud already   manual_dinit.py:57
#                              loaded, skipping
#                     DEBUG    Loading service file             manual_dinit.py:45
#                              appflowy_worker
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/appflowy_worker
#                     DEBUG    Registering service              manual_dinit.py:60
#                              'appflowy_worker' from file
#                              /etc/dinit.d/appflowy_worker
#                     DEBUG    Parsed config for                manual_dinit.py:62
#                              appflowy_worker: {'type':
#                              ['process'], 'command':
#                              ['/usr/local/bin/appflowy_worker
#                              '], 'logfile':
#                              ['/var/log/dinit/appflowy_worker
#                              .log'], 'smooth-recovery':
#                              ['true'], 'depends-on':
#                              ['appflowy_cloud', 'minio']}
#                     INFO     Registered service               manual_dinit.py:96
#                              appflowy_worker (type=process)
#                              with dependencies
#                              ['appflowy_cloud', 'minio']
#                     DEBUG    Service appflowy_worker         manual_dinit.py:101
#                              declares dependency
#                              appflowy_cloud
#                     DEBUG    Service appflowy_worker         manual_dinit.py:101
#                              declares dependency minio
#                     DEBUG    Loading service file boot        manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot
#                     DEBUG    Registering service 'boot' from  manual_dinit.py:60
#                              file /etc/dinit.d/boot
#                     DEBUG    Parsed config for boot: {'type': manual_dinit.py:62
#                              ['internal'], 'waits-for.d':
#                              ['boot.d']}
#                     DEBUG    Service boot is internal;        manual_dinit.py:78
#                              scanning directory
#                              /etc/dinit.d/boot.d for
#                              dependencies
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              admin_frontend for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/admin_fronte
#                              nd
#                     DEBUG    Service admin_frontend already   manual_dinit.py:57
#                              loaded, skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              appflowy_cloud for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/appflowy_clo
#                              ud
#                     DEBUG    Service appflowy_cloud already   manual_dinit.py:57
#                              loaded, skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              appflowy_worker for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/appflowy_wor
#                              ker
#                     DEBUG    Service appflowy_worker already  manual_dinit.py:57
#                              loaded, skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              dbus for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/dbus
#                     DEBUG    Registering service 'dbus' from  manual_dinit.py:60
#                              file /etc/dinit.d/boot.d/dbus
#                     DEBUG    Parsed config for dbus: {'type': manual_dinit.py:62
#                              ['process'], 'command':
#                              ['/usr/bin/dbus-daemon --nofork
#                              --system'], 'logfile':
#                              ['/var/log/dinit/dbus.log']}
#                     INFO     Registered service dbus          manual_dinit.py:96
#                              (type=process) with dependencies
#                              []
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              gotrue for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/gotrue
#                     DEBUG    Service gotrue already loaded,   manual_dinit.py:57
#                              skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              minio for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/minio
#                     DEBUG    Service minio already loaded,    manual_dinit.py:57
#                              skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              nginx for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/nginx
#                     DEBUG    Registering service 'nginx' from manual_dinit.py:60
#                              file /etc/dinit.d/boot.d/nginx
#                     DEBUG    Parsed config for nginx:         manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['/usr/sbin/nginx -g "daemon
#                              off;"'], 'logfile':
#                              ['/var/log/dinit/nginx.log']}
#                     INFO     Registered service nginx         manual_dinit.py:96
#                              (type=process) with dependencies
#                              []
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              postgres for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/postgres
#                     DEBUG    Service postgres already loaded, manual_dinit.py:57
#                              skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              redis for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/redis
#                     DEBUG    Service redis already loaded,    manual_dinit.py:57
#                              skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              setup_postgres_data for service
#                              boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/setup_postgr
#                              es_data
#                     DEBUG    Service setup_postgres_data      manual_dinit.py:57
#                              already loaded, skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              setup_postgres_env for service
#                              boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/setup_postgr
#                              es_env
#                     DEBUG    Service setup_postgres_env       manual_dinit.py:57
#                              already loaded, skipping
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              websockify for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/websockify
#                     DEBUG    Registering service 'websockify' manual_dinit.py:60
#                              from file
#                              /etc/dinit.d/boot.d/websockify
#                     DEBUG    Parsed config for websockify:    manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['/usr/bin/websockify --web
#                              /usr/share/novnc 6080
#                              localhost:5900'], 'logfile':
#                              ['/var/log/dinit/websockify.log'
#                              ], 'smooth-recovery': ['true'],
#                              'restart': ['true']}
#                     INFO     Registered service websockify    manual_dinit.py:96
#                              (type=process) with dependencies
#                              []
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              x11vnc for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/x11vnc
#                     DEBUG    Registering service 'x11vnc'     manual_dinit.py:60
#                              from file
#                              /etc/dinit.d/boot.d/x11vnc
#                     DEBUG    Parsed config for x11vnc:        manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['sudo -E -u ubuntu x11vnc
#                              -forever -shared'], 'logfile':
#                              ['/var/log/dinit/x11vnc.log'],
#                              'smooth-recovery': ['true'],
#                              'restart': ['true'],
#                              'waits-for': ['xvfb'],
#                              'depends-on': ['xvfb']}
#                     DEBUG    Service x11vnc declares          manual_dinit.py:69
#                              waits-for dependency xvfb
#                     INFO     Registered service x11vnc        manual_dinit.py:96
#                              (type=process) with dependencies
#                              ['xvfb', 'xvfb']
#                     DEBUG    Service x11vnc declares         manual_dinit.py:101
#                              dependency xvfb
#                     DEBUG    Loading explicit dependency     manual_dinit.py:109
#                              file /etc/dinit.d/xvfb for
#                              service x11vnc
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/xvfb
#                     DEBUG    Registering service 'xvfb' from  manual_dinit.py:60
#                              file /etc/dinit.d/xvfb
#                     DEBUG    Parsed config for xvfb: {'type': manual_dinit.py:62
#                              ['process'], 'command': ['sudo
#                              -E -u ubuntu Xvfb :1 -screen 0
#                              1280x800x24 -fbdir /var/tmp'],
#                              'logfile':
#                              ['/var/log/dinit/xvfb.log'],
#                              'smooth-recovery': ['true'],
#                              'restart': ['true']}
#                     INFO     Registered service xvfb          manual_dinit.py:96
#                              (type=process) with dependencies
#                              []
#                     DEBUG    Service x11vnc declares         manual_dinit.py:101
#                              dependency xvfb
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              xfce4_session for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/xfce4_sessio
#                              n
#                     DEBUG    Registering service              manual_dinit.py:60
#                              'xfce4_session' from file
#                              /etc/dinit.d/boot.d/xfce4_sessio
#                              n
#                     DEBUG    Parsed config for xfce4_session: manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['sudo -E -u ubuntu bash -c "cd
#                              /home/ubuntu &&
#                              xfce4-session"'], 'logfile':
#                              ['/var/log/dinit/xfce4-session.l
#                              og'], 'restart': ['true'],
#                              'depends-on': ['xvfb']}
#                     INFO     Registered service xfce4_session manual_dinit.py:96
#                              (type=process) with dependencies
#                              ['xvfb']
#                     DEBUG    Service xfce4_session declares  manual_dinit.py:101
#                              dependency xvfb
#                     DEBUG    Found internal dependency file   manual_dinit.py:85
#                              xvfb for service boot
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/boot.d/xvfb
#                     DEBUG    Service xvfb already loaded,     manual_dinit.py:57
#                              skipping
#                     INFO     Registered service boot          manual_dinit.py:96
#                              (type=internal) with
#                              dependencies ['admin_frontend',
#                              'appflowy_cloud',
#                              'appflowy_worker', 'dbus',
#                              'gotrue', 'minio', 'nginx',
#                              'postgres', 'redis',
#                              'setup_postgres_data',
#                              'setup_postgres_env',
#                              'websockify', 'x11vnc',
#                              'xfce4_session', 'xvfb']
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency admin_frontend
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency appflowy_cloud
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency appflowy_worker
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency dbus
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency gotrue
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency minio
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency nginx
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency postgres
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency redis
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency setup_postgres_data
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency setup_postgres_env
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency websockify
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency x11vnc
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency xfce4_session
#                     DEBUG    Service boot declares           manual_dinit.py:101
#                              dependency xvfb
#                     DEBUG    Loading service file dbus        manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/dbus
#                     DEBUG    Service dbus already loaded,     manual_dinit.py:57
#                              skipping
#                     DEBUG    Loading service file dnsmasq     manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/dnsmasq
#                     DEBUG    Registering service 'dnsmasq'    manual_dinit.py:60
#                              from file /etc/dinit.d/dnsmasq
#                     DEBUG    Parsed config for dnsmasq:       manual_dinit.py:62
#                              {'type': ['process'], 'command':
#                              ['/usr/sbin/dnsmasq -d'],
#                              'logfile':
#                              ['/var/log/dinit/dnsmasq.log']}
#                     INFO     Registered service dnsmasq       manual_dinit.py:96
#                              (type=process) with dependencies
#                              []
#                     DEBUG    Loading service file gotrue      manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/gotrue
#                     DEBUG    Service gotrue already loaded,   manual_dinit.py:57
#                              skipping
#                     DEBUG    Skipping shell-script service    manual_dinit.py:43
#                              file gotrue.sh
#                     DEBUG    Loading service file minio       manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/minio
#                     DEBUG    Service minio already loaded,    manual_dinit.py:57
#                              skipping
#                     DEBUG    Loading service file mk_xauth    manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/mk_xauth
#                     DEBUG    Registering service 'mk_xauth'   manual_dinit.py:60
#                              from file /etc/dinit.d/mk_xauth
#                     DEBUG    Parsed config for mk_xauth:      manual_dinit.py:62
#                              {'type': ['scripted'],
#                              'command': ['/usr/bin/sudo -E -u
#                              ubuntu bash -c "touch
#                              $HOME/.Xauthority && xauth add
#                              $DISPLAY $HOME `mcookie`"'],
#                              'logfile':
#                              ['/var/log/dinit/mk_xauth.log']}
#                     INFO     Registered service mk_xauth      manual_dinit.py:96
#                              (type=scripted) with
#                              dependencies []
#                     DEBUG    Loading service file nginx       manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/nginx
#                     DEBUG    Service nginx already loaded,    manual_dinit.py:57
#                              skipping
#                     DEBUG    Loading service file postgres    manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/postgres
#                     DEBUG    Service postgres already loaded, manual_dinit.py:57
#                              skipping
#                     DEBUG    Loading service file redis       manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/redis
#                     DEBUG    Service redis already loaded,    manual_dinit.py:57
#                              skipping
#                     DEBUG    Loading service file             manual_dinit.py:45
#                              setup_postgres_data
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/setup_postgres_data
#                     DEBUG    Service setup_postgres_data      manual_dinit.py:57
#                              already loaded, skipping
#                     DEBUG    Skipping shell-script service    manual_dinit.py:43
#                              file setup_postgres_data.sh
#                     DEBUG    Loading service file             manual_dinit.py:45
#                              setup_postgres_env
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/setup_postgres_env
#                     DEBUG    Service setup_postgres_env       manual_dinit.py:57
#                              already loaded, skipping
#                     DEBUG    Skipping shell-script service    manual_dinit.py:43
#                              file setup_postgres_env.sh
#                     DEBUG    Loading service file websockify  manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/websockify
#                     DEBUG    Service websockify already       manual_dinit.py:57
#                              loaded, skipping
#                     DEBUG    Loading service file x11vnc      manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/x11vnc
#                     DEBUG    Service x11vnc already loaded,   manual_dinit.py:57
#                              skipping
#                     DEBUG    Loading service file             manual_dinit.py:45
#                              xfce4_session
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/xfce4_session
#                     DEBUG    Service xfce4_session already    manual_dinit.py:57
#                              loaded, skipping
#                     DEBUG    Loading service file xvfb        manual_dinit.py:45
#                     DEBUG    Parsing service definition file  manual_dinit.py:53
#                              /etc/dinit.d/xvfb
#                     DEBUG    Service xvfb already loaded,     manual_dinit.py:57
#                              skipping
#                     DEBUG    Resolving dependencies for      manual_dinit.py:165
#                              service 'boot':
#                              ['admin_frontend',
#                              'appflowy_cloud',
#                              'appflowy_worker', 'dbus',
#                              'gotrue', 'minio', 'nginx',
#                              'postgres', 'redis',
#                              'setup_postgres_data',
#                              'setup_postgres_env',
#                              'websockify', 'x11vnc',
#                              'xfce4_session', 'xvfb']
#                     DEBUG    Service 'boot' depends on       manual_dinit.py:167
#                              'admin_frontend'; starting
#                              dependency
#                     DEBUG    Resolving dependencies for      manual_dinit.py:165
#                              service 'admin_frontend':
#                              ['appflowy_cloud']
# ...
#                     DEBUG    Service 'boot' depends on       manual_dinit.py:167
#                              'xfce4_session'; starting
#                              dependency
#                     DEBUG    Resolving dependencies for      manual_dinit.py:165
#                              service 'xfce4_session':
#                              ['xvfb']
#                     DEBUG    Service 'xfce4_session' depends manual_dinit.py:167
#                              on 'xvfb'; starting dependency
#                     INFO     Starting service                manual_dinit.py:170
#                              'xfce4_session'
#                              (type=process)...
#                     DEBUG    Dispatching service             manual_dinit.py:172
#                              'xfce4_session' to handler for
#                              type 'process'
#                     INFO     Service 'xfce4_session' started manual_dinit.py:185
#                              successfully.
#                     DEBUG    Service 'boot' depends on       manual_dinit.py:167
#                              'xvfb'; starting dependency
#                     INFO     Starting service 'boot'         manual_dinit.py:170
#                              (type=internal)...
#                     DEBUG    Dispatching service 'boot' to   manual_dinit.py:172
#                              handler for type 'internal'
#                     INFO     Service 'boot' started          manual_dinit.py:185
#                              successfully.
# [06/05/25 00:33:11] INFO     #### ACTION ##### key               computer.py:154
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              key -- alt+F10
# [06/05/25 00:33:12] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _c6d387373f4e49d7b7183e6987313697.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _c6d387373f4e49d7b7183e6987313697.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _c6d387373f4e49d7b7183e6987313697.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              key -- alt+F10
# [06/05/25 00:33:13] INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 644 283 click 1
# [06/05/25 00:33:14] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _b41f86df69a3490ebba099766f2a03c3.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _b41f86df69a3490ebba099766f2a03c3.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _b41f86df69a3490ebba099766f2a03c3.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 644 283 click 1
#                     INFO     #### ACTION ##### type              computer.py:154
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              type --delay 12 --
#                              admin@example.com
# [06/05/25 00:33:15] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _c5fd9700dd5c40c0a12968a303a221b8.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _c5fd9700dd5c40c0a12968a303a221b8.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _c5fd9700dd5c40c0a12968a303a221b8.p
#                              ng
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 644 336 click 1
# [06/05/25 00:33:16] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _ebb6ec8b8d3a4d72b6b48f5be8882449.p
#                              ng
# [06/05/25 00:33:17] INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _ebb6ec8b8d3a4d72b6b48f5be8882449.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _ebb6ec8b8d3a4d72b6b48f5be8882449.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 644 336 click 1
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 644 497 click 1
# [06/05/25 00:33:18] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _6d4317e3c80f45a8918dd80a9ffadef0.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _6d4317e3c80f45a8918dd80a9ffadef0.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _6d4317e3c80f45a8918dd80a9ffadef0.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 644 497 click 1
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 644 471 click 1
# [06/05/25 00:33:19] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _c22fa24bdadf405695d6af31064f6ea3.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _c22fa24bdadf405695d6af31064f6ea3.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _c22fa24bdadf405695d6af31064f6ea3.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 644 471 click 1
#                     INFO     #### ACTION ##### type              computer.py:154
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              type --delay 12 -- 123456
# [06/05/25 00:33:20] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _94a88f14f45442d68357df2fd8e7c9ca.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _94a88f14f45442d68357df2fd8e7c9ca.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _94a88f14f45442d68357df2fd8e7c9ca.p
#                              ng
# [06/05/25 00:33:21] INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 644 524 click 1
# [06/05/25 00:33:22] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _e56473f3eb154108b05ba57c9c32550e.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _e56473f3eb154108b05ba57c9c32550e.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _e56473f3eb154108b05ba57c9c32550e.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 644 524 click 1
#                     INFO     #### ACTION ##### key               computer.py:154
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              key -- alt+F10
# [06/05/25 00:33:23] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _5f97cbd934114511b614c34f3e01eba9.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _5f97cbd934114511b614c34f3e01eba9.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _5f97cbd934114511b614c34f3e01eba9.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              key -- alt+F10
# Environment resetting (runs setup)...
# Initial observation: Observation(screenshot=None, text=We need to expand our Richmond district portfolio. Please add the Richmond Garden House (identifier ...)

# %%
import base64
from io import BytesIO
from PIL import Image
from IPython.display import display

for i in range(8):
    print(f"========= Step {i + 1} =========")
    action, done = await agent.predict(obs)
    print(f"Agent's action: {action}")

    obs, reward, terminated, info = await env.step(action)

    if done or terminated:
        break
# Out:
# ========= Step 1 =========
# Agent's action: [ScreenshotFetch(type='screenshot', logs={'id': 'resp_6840e5d904b4819ead95b357b9e87c520a4ee8f45226ed74', 'created_at': 1749083609.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'cu_6840e5d9b404819eb99274241245c35e0a4ee8f45226ed74', 'action': {'type': 'screenshot'}, 'call_id': 'call_lW0uPwAjUHwgnuCf9QOZSigy', 'pending_safety_checks': [], 'status': 'in_progress', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': None, 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'auto', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 573, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 15, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 588}, 'user': None, 'store': True})]
# Step produced stderr: [06/05/25 00:33:32] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### screenshot        computer.py:154
#                     INFO     Taking screenshot....               computer.py:303
# [06/05/25 00:33:33] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _56d78dcfb01a4b4d9b92c83914a025db.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _56d78dcfb01a4b4d9b92c83914a025db.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _56d78dcfb01a4b4d9b92c83914a025db.p
#                              ng
# ========= Step 2 =========
# Agent's action: [ClickAction(type='click', logs={'id': 'resp_6840e5ddf0b8819e885ed5db2840e0eb0a4ee8f45226ed74', 'created_at': 1749083613.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'rs_6840e5dfabf4819e8ca2b866893955ca0a4ee8f45226ed74', 'summary': [], 'type': 'reasoning', 'encrypted_content': None, 'status': None}, {'id': 'cu_6840e5e11100819eb8a4930266315d450a4ee8f45226ed74', 'action': {'button': 'left', 'type': 'click', 'x': 80, 'y': 108}, 'call_id': 'call_D2fsnWM5oGOW8r9YLMKHF2oG', 'pending_safety_checks': [], 'status': 'completed', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': 'resp_6840e5d904b4819ead95b357b9e87c520a4ee8f45226ed74', 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'default', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 1171, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 168, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 1339}, 'user': None, 'store': True}, point=Point(x=100, y=112), button='left', pattern=None, hold_keys=None)]
# Step produced stderr: [06/05/25 00:33:39] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
# [06/05/25 00:33:40] INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 100 112 click 1
# [06/05/25 00:33:41] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _efdae510d158415699faf32801afbf37.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _efdae510d158415699faf32801afbf37.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _efdae510d158415699faf32801afbf37.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 100 112 click 1
# ========= Step 3 =========
# Agent's action: [ClickAction(type='click', logs={'id': 'resp_6840e5e5c460819e836a889cc0276a970a4ee8f45226ed74', 'created_at': 1749083621.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'rs_6840e5e7ba78819e9c4c2a882f039e0b0a4ee8f45226ed74', 'summary': [], 'type': 'reasoning', 'encrypted_content': None, 'status': None}, {'id': 'cu_6840e5e89e88819e9e3e8f2e82866ac40a4ee8f45226ed74', 'action': {'button': 'left', 'type': 'click', 'x': 264, 'y': 76}, 'call_id': 'call_gp4l9ruMlenpQf9N0SiRy1cS', 'pending_safety_checks': [], 'status': 'completed', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': 'resp_6840e5ddf0b8819e885ed5db2840e0eb0a4ee8f45226ed74', 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'default', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 1927, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 100, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 2027}, 'user': None, 'store': True}, point=Point(x=330, y=79), button='left', pattern=None, hold_keys=None)]
# Step produced stderr: [06/05/25 00:33:47] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 330 79 click 1
# [06/05/25 00:33:48] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _11063936d19e46ddb39cb543aa36c159.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _11063936d19e46ddb39cb543aa36c159.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _11063936d19e46ddb39cb543aa36c159.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 330 79 click 1
# ========= Step 4 =========
# Agent's action: [ClickAction(type='click', logs={'id': 'resp_6840e5ed8250819e8107bdb266af7a360a4ee8f45226ed74', 'created_at': 1749083629.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'cu_6840e5efa7a0819e94b99bfc4ca6c7ed0a4ee8f45226ed74', 'action': {'button': 'left', 'type': 'click', 'x': 257, 'y': 75}, 'call_id': 'call_56M0OWjTjcyeSaZ8wUxPFsZy', 'pending_safety_checks': [], 'status': 'completed', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': 'resp_6840e5e5c460819e836a889cc0276a970a4ee8f45226ed74', 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'default', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 2614, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 24, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 2638}, 'user': None, 'store': True}, point=Point(x=321, y=78), button='left', pattern=None, hold_keys=None)]
# Step produced stderr: [06/05/25 00:33:54] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 321 78 click 1
# [06/05/25 00:33:55] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _dc5bf5b2eadd44b68c19bb7befd6ceeb.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _dc5bf5b2eadd44b68c19bb7befd6ceeb.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _dc5bf5b2eadd44b68c19bb7befd6ceeb.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 321 78 click 1
# ========= Step 5 =========
# Agent's action: [WaitAction(type='wait', logs={'id': 'resp_6840e5f493c8819e942b00232646325e0a4ee8f45226ed74', 'created_at': 1749083636.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'cu_6840e5f79844819eafd803949c22d5fc0a4ee8f45226ed74', 'action': {'type': 'wait'}, 'call_id': 'call_eegrdtCuZ5XQdIuukDaOV82h', 'pending_safety_checks': [], 'status': 'completed', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': 'resp_6840e5ed8250819e8107bdb266af7a360a4ee8f45226ed74', 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'default', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 3228, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 12, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 3240}, 'user': None, 'store': True}, time=1000)]
# Step produced stderr: [06/05/25 00:34:03] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### wait              computer.py:154
# [06/05/25 00:34:04] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _f9be6279bb4e4feebf56995ecd971987.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _f9be6279bb4e4feebf56995ecd971987.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _f9be6279bb4e4feebf56995ecd971987.p
#                              ng
# ========= Step 6 =========
# Agent's action: [ClickAction(type='click', logs={'id': 'resp_6840e5fce0bc819e99d22f326dcd65730a4ee8f45226ed74', 'created_at': 1749083644.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'cu_6840e5ffb1f8819e801d9dd889730a6a0a4ee8f45226ed74', 'action': {'button': 'left', 'type': 'click', 'x': 268, 'y': 75}, 'call_id': 'call_0ElpjhSDNOiw9yV9JDt0x0Ii', 'pending_safety_checks': [], 'status': 'completed', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': 'resp_6840e5f493c8819e942b00232646325e0a4ee8f45226ed74', 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'default', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 3830, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 24, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 3854}, 'user': None, 'store': True}, point=Point(x=335, y=78), button='left', pattern=None, hold_keys=None)]
# Step produced stderr: [06/05/25 00:34:11] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 335 78 click 1
# [06/05/25 00:34:12] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _d35b4fc41d7746009bd4e1d7ff38313f.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _d35b4fc41d7746009bd4e1d7ff38313f.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _d35b4fc41d7746009bd4e1d7ff38313f.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 335 78 click 1
# ========= Step 7 =========
# Agent's action: [ClickAction(type='click', logs={'id': 'resp_6840e60536b8819e865c51bfce7f87610a4ee8f45226ed74', 'created_at': 1749083653.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'rs_6840e607f2bc819eb158f608197c4a360a4ee8f45226ed74', 'summary': [], 'type': 'reasoning', 'encrypted_content': None, 'status': None}, {'id': 'cu_6840e608b624819e9d68122721f0522c0a4ee8f45226ed74', 'action': {'button': 'left', 'type': 'click', 'x': 378, 'y': 76}, 'call_id': 'call_vDtbeyKzfodZVshI91EmUe2F', 'pending_safety_checks': [], 'status': 'completed', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': 'resp_6840e5fce0bc819e99d22f326dcd65730a4ee8f45226ed74', 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'default', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 4444, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 100, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 4544}, 'user': None, 'store': True}, point=Point(x=472, y=79), button='left', pattern=None, hold_keys=None)]
# Step produced stderr: [06/05/25 00:34:20] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 472 79 click 1
# [06/05/25 00:34:21] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _96cd6d0b60f04a9c8573bd952db94387.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _96cd6d0b60f04a9c8573bd952db94387.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _96cd6d0b60f04a9c8573bd952db94387.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 472 79 click 1
# ========= Step 8 =========
# Agent's action: [ClickAction(type='click', logs={'id': 'resp_6840e60e09d0819ead08f99e46e4b0bf0a4ee8f45226ed74', 'created_at': 1749083662.0, 'error': None, 'incomplete_details': None, 'instructions': None, 'metadata': {}, 'model': 'computer-use-preview-2025-03-11', 'object': 'response', 'output': [{'id': 'rs_6840e610e258819eaf28792389b4c5890a4ee8f45226ed74', 'summary': [], 'type': 'reasoning', 'encrypted_content': None, 'status': None}, {'id': 'cu_6840e6120390819e95511f48f64e46a80a4ee8f45226ed74', 'action': {'button': 'left', 'type': 'click', 'x': 721, 'y': 390}, 'call_id': 'call_NlXgyLBsASTZRNbewkpR8gSA', 'pending_safety_checks': [], 'status': 'completed', 'type': 'computer_call'}], 'parallel_tool_calls': True, 'temperature': 1.0, 'tool_choice': 'auto', 'tools': [{'display_height': 768, 'display_width': 1024, 'environment': 'linux', 'type': 'computer_use_preview'}], 'top_p': 1.0, 'background': False, 'max_output_tokens': None, 'previous_response_id': 'resp_6840e60536b8819e865c51bfce7f87610a4ee8f45226ed74', 'reasoning': {'effort': 'medium', 'generate_summary': None, 'summary': None}, 'service_tier': 'default', 'status': 'completed', 'text': {'format': {'type': 'text'}}, 'truncation': 'auto', 'usage': {'input_tokens': 5134, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens': 141, 'output_tokens_details': {'reasoning_tokens': 0}, 'total_tokens': 5275}, 'user': None, 'store': True}, point=Point(x=901, y=406), button='left', pattern=None, hold_keys=None)]
# Step produced stderr: [06/05/25 00:34:29] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 901 406 click 1
# [06/05/25 00:34:30] INFO     #### SHELL ##### DISPLAY=:1 scrot   computer.py:352
#                              -p
#                              /home/ubuntu/screenshots/screenshot
#                              _e5faf03f62c042d8a016473194011b6c.p
#                              ng
#                     INFO     #### SHELL ##### convert            computer.py:352
#                              /home/ubuntu/screenshots/screenshot
#                              _e5faf03f62c042d8a016473194011b6c.p
#                              ng -resize 1280x800! -define
#                              png:compression-level=9
#                              /home/ubuntu/screenshots/screenshot
#                              _e5faf03f62c042d8a016473194011b6c.p
#                              ng
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 901 406 click 1

# %%
result = await env.evaluate()
print(result)
# Out:
# grade produced stderr:
# [06/05/25 00:36:23] DEBUG    Using selector: EpollSelector selector_events.py:64
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 1159 79 click 1
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 1159 79 click 1
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 904 127 click 1
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 904 127 click 1
#                     INFO     #### ACTION ##### left_click        computer.py:154
#                     INFO     #### CLICK ##### left_click         computer.py:230
#                     INFO     #### SHELL ##### DISPLAY=:1 xdotool computer.py:352
#                              mousemove 771 179 click 1
#                     INFO     #### SHELL FINISHED, CONTENT        computer.py:364
#                              BLOCKING ##### DISPLAY=:1 xdotool
#                              mousemove 771 179 click 1
#                     DEBUG    filter_extra_rows: extra row:         grading.py:96
#                              {'ticket id': 'ops 105', 'summary':
#                              'stock extra linens summer',
#                              'property id': 'region wide', 'type':
#                              'inventory', 'assignee': 'rina', 'due
#                              date': 'may 24 2025', 'status': 'to
#                              do'}
#                     WARNING  score_matching_table: expected:      grading.py:176
#                              {'property id': 'prop 001',
#                              'nickname': 'telegraph loft',
#                              'neighbourhood': 'north beach',
#                              'beds': '2', 'status': 'active',
#                              'occupancy 30d': '0 87', 'avg
#                              rating': '4 87', 'host type':
#                              'individual', 'next turnover': '2025
#                              05 18 11 00'}
#                     INFO     score_matching_table: matching cell: grading.py:190
#                              prop 001 -> prop 001
#                     WARNING  score_matching_table: expected:      grading.py:176
#                              {'property id': 'prop 002',
#                              'nickname': 'mission patio home',
#                              'neighbourhood': 'mission', 'beds':
#                              '3', 'status': 'active', 'occupancy
#                              30d': '0 72', 'avg rating': '4 55',
#                              'host type': 'individual', 'next
#                              turnover': '2025 05 17 15 00'}
#                     INFO     score_matching_table: matching cell: grading.py:190
#                              prop 002 -> prop 002
#                     WARNING  score_matching_table: expected:      grading.py:176
#                              {'property id': 'prop 003',
#                              'nickname': 'soma micro studio',
#                              'neighbourhood': 'soma', 'beds':
#                              '1', 'status': 'paused renovation',
#                              'occupancy 30d': '0 0', 'avg
#                              rating': '', 'host type': 'master
#                              lease', 'next turnover': ''}
#                     INFO     score_matching_table: matching cell: grading.py:190
#                              prop 003 -> prop 003
#                     WARNING  score_matching_table: expected:      grading.py:176
#                              {'property id': 'prop 004',
#                              'nickname': 'marina view suite',
#                              'neighbourhood': 'marina', 'beds':
#                              '2', 'status': 'active', 'occupancy
#                              30d': '0 91', 'avg rating': '4 93',
#                              'host type': 'individual', 'next
#                              turnover': '2025 05 16 12 00'}
#                     INFO     score_matching_table: matching cell: grading.py:190
#                              prop 004 -> prop 004
#                     WARNING  score_matching_table: expected:      grading.py:176
#                              {'property id': 'prop 005',
#                              'nickname': 'nob hill victorian',
#                              'neighbourhood': 'nob hill', 'beds':
#                              '4', 'status': 'coming soon',
#                              'occupancy 30d': '', 'avg rating':
#                              '', 'host type': 'master lease',
#                              'next turnover': ''}
#                     INFO     score_matching_table: matching       grading.py:192
#                              cells: 4, total cells: 45, score:
#                              0.08888888888888889
#                     WARNING  score_matching_table: expected:      grading.py:176
#                              {'property id': 'prop 007',
#                              'nickname': 'richmond garden house',
#                              'neighbourhood': 'richmond', 'beds':
#                              '3', 'status': 'active', 'occupancy
#                              30d': '0 78', 'avg rating': '4 72',
#                              'host type': 'master lease', 'next
#                              turnover': '2025 05 21 14 00'}
#                     INFO     score_matching_table: matching       grading.py:192
#                              cells: 0, total cells: 9, score: 0.0
# 0.01577777777777778

# %%
await env.close()

# %%
from hud import run_job

job = await run_job(
    OperatorAgent,
    first_task,
    "appflowy-first-task",
    max_steps_per_task=20,
    max_concurrent_tasks=20,
    auto_reply_question=True,
)
# Out:
# 100%|████████████████████████████████████████| 20/20 [4:13<0:00, 4.7 steps/min]
