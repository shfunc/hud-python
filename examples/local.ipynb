# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
load_dotenv()

from hud import gym
from hud.types import CustomGym

# %%
env = await gym.make(CustomGym(
    location="local",
    controller_source_dir="../environments/qa_controller"
))

# %%
await env.client.execute(["ls","-l"])

# %%
from hud.utils.config import HudStyleConfig

await env.client.invoke(HudStyleConfig(
    function="step.step",
    args=["answer: what is the capital of the moon?"]
))
